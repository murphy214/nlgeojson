# %%
import nlgeojson as nl
import mapkit as mk
import os
import time
import pandas as pd
import pipegeohash as p

# %%
lines = mk.get_database('la_routes')
points = pd.read_csv('chiraq.csv')
counties = mk.get_normal_db('counties',tablename='flat')
blocks = p.map_table(points,12,map_only=True)

# %%
# creating get size of function
def getsize(filename):
    statinfo = os.stat(filename)
    return float(statinfo.st_size) / (1000 ** 2)

def speed_test(args,type,mbsize,function):
    s = time.time()
    if type == 'points':
        filename = 'points_old.geojson'
        function(args,filename=filename,list=True)
    if type == 'lines':
        filename = 'lines_old.geojson'
        function(args,filename,list=True)

    
    e = time.time() - s
    
    speed = mbsize / e
    return speed

# %% [markdown]
# ### Lines
# Lines accepts two forms of input columns one of which is requred. Either a st_asewkt field is required with in a string from a posgis database, or a field called coords that contains literally a string representation of the geojson coordinate list.
#
# My algorithm heavily prefers input from coords fields as nothing is required to parse into geojson correctly. So if using st_asekwt be aware that behind the scenes its parsing out your coords into coord strings anyway and it may be worth it to add a field in your database for this.

# %%
s = time.time()
nl.make_lines(lines,'lines.geojson')
e = time.time() - s

# getting size of geojson file
mbsizel = getsize('lines.geojson')
speedline = mbsizel / e
print 'Parsed lines geojson at %s mb / s' % (speedline)
# Out:
# Wrote lines.geojson filename to geojson file.
# Parsed lines geojson at 59.7069874057 mb / s

# %% [markdown]
# ### Points
#
# Points are quite simple have a field with 'LAT' or 'LONG' in denoting lat / long fields to be parsed into points within the geojson struture.

# %%
s = time.time()
nl.make_points(points,'points.geojson')
e = time.time() - s

# getting size of geojson file
mbsizep = getsize('points.geojson')
speedpoint = mbsizep / e
print 'Parsed points geojson at %s mb / s' % (speedpoint)
# Out:
# Wrote geojson file to points.geojson.
# Parsed points geojson at 40.6154139762 mb / s

# %% [markdown]
# ### Polygons
#
# On the other hand polygons are the most complex to get into a field. They contain a structured string to denote multipolygons about one area for things like states. This makes it so you can have complex geometries that can still be aggregated about a single field. However makes getting tables into this format sort of a one way street, my module polygon logic parses shp or kml files into complex geometries (holes,multipolygon) and outputs a dataframe table.
#
# The idea here is once the table is made once you can throw it in postgres and when you use something like ult to relate all points to a given polygon, group by your polygon area on the points df, and have a super easy table join to the polygon dataframe.
#
# Basically it works and thats all I care about currently.

# %%
s = time.time()
nl.make_polygons(counties,'polygons.geojson')
e = time.time() - s

# getting size of geojson file
mbsize = getsize('polygons.geojson')
speedpolygon = mbsize / e
print 'Parsed polygons geojson at %s mb / s' % (speedpolygon)
# Out:
# Wrote polygons.geojson filename to geojson file.
# Parsed polygons geojson at 71.7193896661 mb / s

# %% [markdown]
# ### Blocks
# Blocks can accept either a geohash field or the for cardinal fields NORTH,SOUTH,EAST,WEST in the columns of the df.

# %%
s = time.time()
nl.make_blocks(blocks,'blocks.geojson')
e = time.time() - s

# getting size of geojson file
mbsizeb = getsize('blocks.geojson')
speedblock = mbsizeb / e
print 'Parsed blocks geojson at %s mb / s' % (speedblock)
# Out:
# Wrote blocks.geojson filename to geojson file.
# Parsed blocks geojson at 31.0193727936 mb / s

# %% [markdown]
# ### Comparison again Old Modules (pipegeohash)
# The following are the comparison of speed between this and the old geojson parsing library pipegeohash. Polygons will be omitted as support like this was never implemented entirely.

# %%
import pipegeojson as pg

# creating dataframe for first speed
speeds = pd.DataFrame([speedpoint,speedline,speedblock],columns=['NLGEOJSON (mb/s)'])
speeds
print lines

pspeed = speed_test(points[:1000],'points',mbsizep,pg.make_points)
lspeed = speed_test(lines[:1000],'lines',mbsizel,pg.make_postgis_lines)
bspeed = speed_test(blocks[:1000],'blocks',mbsizeb,pg.make_blocks)
speeds['PIPEGEOJSON (mb/s)'] = [pspeed,lspeed,bspeed]
speeds
# Out:
#            gid       linearid              fullname rttyp  mtfcc  \
# 0           82  1104486642780          State Rte 14     S  S1200
# 1        93775  1101583261345                  None  None  S1400
# 2        93902  1101576692134          N Pannes Ave     M  S1400
# 3        94047  1101583239809                  None  None  S1400
# 4        94459  1101583265329                  None  None  S1400
# 5        95145  1101583228688                  None  None  S1400
# 6        95137  1101576712568           Reisner Way     M  S1400
# 7        95326  1101583249549                  None  None  S1400
# 8        95803  1101576668435              Arbor Ln     M  S1400
# 9        95695  1101576730804        Saint Louis Ct     M  S1400
# 10       95958  1101576674905             Menlo Ave     M  S1400
# 11       96146  1101576700801           Carmona Ave     M  S1400
# 12       98877  1101583242176                  None  None  S1400
# 13       96719  1101576731603           Toberman St     M  S1400
# 14       98391  1101576759212        Lindaraxa Park     M  S1400
# 15       97032  1101576721537           Edinburg Ct     M  S1400
# 16       97052  1101576730997          Stichman Ave     M  S1400
# 17       97342  1101583250206                  None  None  S1400
# 18       97402  1101576735759          Crestview Ct     M  S1400
# 19       97906  1101576729736           Rockwood St     M  S1400
# 20       97981  1101583263141                  None  None  S1400
# 21       97999  1101576759836  Charles E Young Dr W     M  S1400
# 22       98123  1101583240598                  None  None  S1400
# 23       98239  1101576696692             Warren Pl     M  S1400
# 24       98306  1101583236051                  None  None  S1400
# 25       98350  1101583273009                  None  None  S1400
# 26       98356  1101576732138          Virginia Ave     M  S1400
# 27       98671  1101576729403          Redfield Ave     M  S1400
# 28       98676  1101583233570              Alley 12     M  S1730
# 29       98955  1101576744324      S Aldenville Ave     M  S1400
# ...        ...            ...                   ...   ...    ...
# 145691  104619  1101584091148                  None  None  S1740
# 145692  104620  1101584092391                  None  None  S1740
# 145693  104621  1101583236729                  None  None  S1400
# 145694  104622  1101576728436           Palomino Dr     M  S1400
# 145695  104623  1101583259866                  None  None  S1400
# 145696  104624  1101583236541                  None  None  S1400
# 145697  104625  1101576666305            175th St E     M  S1500
# 145698  104711  1101576758523      Spring Canyon Ln     M  S1400
# 145699  104626  1101576761914          Bob's Gap Rd     M  S1400
# 145700  104627  1101584092291                  None  None  S1740
# 145714  @bounds@[[-118.152088, 34.504628], [-118.13156...     0.023086
# 145715  @bounds@[[-117.902239, 34.506256], [-117.90193...     0.000990
# 145716  @bounds@[[-117.914037, 34.506458], [-117.90531...     0.008719
# 145717  @bounds@[[-118.240405, 34.505939], [-118.23943...     0.002309
# 145718  @bounds@[[-118.179311, 34.507697], [-118.17885...     0.002327
# 145719  @bounds@[[-118.184695, 34.506907], [-118.18145...     0.003954
# 145720  @bounds@[[-118.182342, 34.509709], [-118.18231...     0.001154
#
#                                                 st_asewkt
# 0       SRID=4326;MULTILINESTRING((-118.505568 34.3419...
# 1       SRID=4326;MULTILINESTRING((-118.30853 33.92022...
# 2       SRID=4326;MULTILINESTRING((-118.202971 33.9016...
# 3       SRID=4326;MULTILINESTRING((-118.359439 33.8988...
# 4       SRID=4326;MULTILINESTRING((-118.358253 33.9600...
# 5       SRID=4326;MULTILINESTRING((-118.331999 33.9358...
# 6       SRID=4326;MULTILINESTRING((-118.175445 33.9531...
# 7       SRID=4326;MULTILINESTRING((-118.463221 33.9946...
# 8       SRID=4326;MULTILINESTRING((-118.330036 33.9003...
# 9       SRID=4326;MULTILINESTRING((-118.388995 34.0102...
# 10      SRID=4326;MULTILINESTRING((-118.289223 33.9827...
# 11      SRID=4326;MULTILINESTRING((-118.365575 34.0282...
# 12      SRID=4326;MULTILINESTRING((-118.030732 34.0976...
# 13      SRID=4326;MULTILINESTRING((-118.278662 34.0387...
# 14      SRID=4326;MULTILINESTRING((-118.12322 34.09953...
# 15      SRID=4326;MULTILINESTRING((-117.769424 34.0473...
# 16      SRID=4326;MULTILINESTRING((-117.989792 34.0494...
# 17      SRID=4326;MULTILINESTRING((-118.121144 34.0604...
# 18      SRID=4326;MULTILINESTRING((-118.424993 34.0621...
# 19      SRID=4326;MULTILINESTRING((-118.181123 34.0474...
# 20      SRID=4326;MULTILINESTRING((-118.038608 34.0502...
# 21      SRID=4326;MULTILINESTRING((-118.439713 34.0723...
# 22      SRID=4326;MULTILINESTRING((-117.942845 34.0865...
# 23      SRID=4326;MULTILINESTRING((-117.756645 34.0872...
# 24      SRID=4326;MULTILINESTRING((-118.077798 34.0889...
# 25      SRID=4326;MULTILINESTRING((-118.079853 34.0895...
# 26      SRID=4326;MULTILINESTRING((-118.307801 34.0919...
# 27      SRID=4326;MULTILINESTRING((-118.188315 34.1029...
# 28      SRID=4326;MULTILINESTRING((-117.724565 34.1039...
# 29      SRID=4326;MULTILINESTRING((-117.895336 34.0839...
# ...                                                   ...
# 145691  SRID=4326;MULTILINESTRING((-118.224552 34.4785...
# 145692  SRID=4326;MULTILINESTRING((-118.139585 34.4733...
# 145693  SRID=4326;MULTILINESTRING((-118.535941 34.4639...
# 145694  SRID=4326;MULTILINESTRING((-118.173712 34.4747...
# 145695  SRID=4326;MULTILINESTRING((-118.72638 34.47484...
# 145696  SRID=4326;MULTILINESTRING((-118.390395 34.4764...
# 145697  SRID=4326;MULTILINESTRING((-117.817829 34.4759...
# 145698  SRID=4326;MULTILINESTRING((-118.048602 34.5687...
# 145699  SRID=4326;MULTILINESTRING((-117.835078 34.4769...
# 145700  SRID=4326;MULTILINESTRING((-118.135126 34.4734...
# 145701  SRID=4326;MULTILINESTRING((-117.835352 34.4782...
# 145702  SRID=4326;MULTILINESTRING((-118.455405 34.4754...
# 145703  SRID=4326;MULTILINESTRING((-118.300476 34.4500...
# 145704  SRID=4326;MULTILINESTRING((-118.30025 34.45297...
# 145705  SRID=4326;MULTILINESTRING((-118.111526 34.5091...
# 145706  SRID=4326;MULTILINESTRING((-118.608066 34.4993...
# 145707  SRID=4326;MULTILINESTRING((-118.615301 34.5024...
# 145708  SRID=4326;MULTILINESTRING((-118.221871 34.5039...
# 145709  SRID=4326;MULTILINESTRING((-118.218164 34.5024...
# 145710  SRID=4326;MULTILINESTRING((-118.164328 34.5116...
# 145711  SRID=4326;MULTILINESTRING((-118.169122 34.5063...
# 145712  SRID=4326;MULTILINESTRING((-118.155514 34.5082...
# 145713  SRID=4326;MULTILINESTRING((-118.137163 34.5066...
# 145714  SRID=4326;MULTILINESTRING((-118.131569 34.4986...
# 145715  SRID=4326;MULTILINESTRING((-117.902013 34.5055...
# 145716  SRID=4326;MULTILINESTRING((-117.914037 34.5064...
# 145717  SRID=4326;MULTILINESTRING((-118.239432 34.5059...
# 145718  SRID=4326;MULTILINESTRING((-118.178855 34.5055...
# 145719  SRID=4326;MULTILINESTRING((-118.184695 34.5069...
# 145720  SRID=4326;MULTILINESTRING((-118.182315 34.5085...
#
# [145721 rows x 10 columns]
# Wrote points_old.geojson to geojson.
# Wrote lines_old.geojson to geojson.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-9130e34c169e> in <module>()
#       8 pspeed = speed_test(points[:1000],'points',mbsizep,pg.make_points)
#       9 lspeed = speed_test(lines[:1000],'lines',mbsizel,pg.make_postgis_lines)
# ---> 10 bspeed = speed_test(blocks[:1000],'blocks',mbsizeb,pg.make_blocks)
#      11 speeds['PIPEGEOJSON (mb/s)'] = [pspeed,lspeed,bspeed]
#      12 speeds
#
# <ipython-input-4-c45370beb808> in speed_test(args, type, mbsize, function)
#      14     if type == 'blocks':
#      15         filename = 'blocks_old.geojson'
# ---> 16         function(args,filename=filename,list=True)
#      17
#      18     e = time.time() - s
#
# //anaconda/lib/python2.7/site-packages/pipegeojson.pyc in make_blocks(csvfile, **kwargs)
#     950                                 copos.append(count)
#     951                 count += 1
# --> 952         coposbounds = [copos[0],copos[-1]]
#     953
#     954         # checking to see if a header and row value needs to
#
# IndexError: list index out of range

# %%
'''
pspeed = speed_test(points,'points',pg.make_points)
lspeed = speed_test(lines,'lines',pg.make_lines)
bspeed = speed_test(blocks,'blocks',pg.make_blocks)
[pspeed,lspeed,bspeed]
'''
